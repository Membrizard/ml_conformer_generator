# %%
from src.mlconfgen.utils.weights_manager import WeightsManager

manager = WeightsManager()

manager.resolve('adj_mat_seer_chembl_1_39.onnx')
# Out:
# 2026-09-17 14:50:10 | INFO | [MLConfGen] Downloading weights ...
# 2026-09-17 14:50:10 | INFO | HTTP Request: HEAD https://huggingface.co/Membrizard/ml_conformer_generator/resolve/main/adj_mat_seer_chembl_1_39.onnx "HTTP/1.1 404 Not Found"
# 2026-09-17 14:50:10 | ERROR | [MLConfGen] Download failed due to: 404 Client Error. (Request ID: Root=1-6aabf012-582edda3597784bb27308e0a;da7561f0-77fd-41f3-b461-be3f8da98ffd)
#
# Entry Not Found for url: https://huggingface.co/Membrizard/ml_conformer_generator/resolve/main/adj_mat_seer_chembl_1_39.onnx.
# 2026-09-17 14:50:10 | INFO | [MLConfGen] Download complete
# PosixPath('.weights/adj_mat_seer_chembl_1_39.onnx')
